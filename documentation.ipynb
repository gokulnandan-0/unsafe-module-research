# %% [markdown]
# # **PROBLEM STATEMENT**
# ### **Overview:**
# Your task is to secure the Pandas library and its dependencies in a
# Python environment, ensuring safe operation particularly in restricted or "jailed"
# setups. You will identify potential security risks involving unsafe system operations
# and mitigate them.
# ### **Background:**
# Pandas is extensively used for data manipulation and analysis. In
# environments where security is paramount, especially web-based applications, it is
# crucial to restrict the library's capabilities to prevent unauthorized system access
# (including data access).
# ### **Challenge Details:**
# 1. Dependency Analysis: Identify and list all dependencies of the Pandas
# library. Narrow down these dependencies to a subset that could potentially
# include unsafe operations related to system access (e.g., sys, os, requests
# modules).
# 2. Code Analysis: Analyze the source code of Pandas and its critical
# dependencies. Identify all functions and methods in these packages that
# could invoke unsafe operations. Map out a call graph for Pandas and the
# selected dependencies to see which high-level functions can lead to these
# unsafe operations.
# 3. Pruning Unsafe Features: Propose methods to modify or restrict access to
# these unsafe functions. Ensure that core functionalities of Pandas and its
# dependencies remain intact and usable while enhancing security.
# 4. Documentation: Document your findings, including a list of dependencies
# analyzed, identified risky functions, and your proposed solutions. Explain
# your approach and the steps taken to secure the library and its
# dependencies, providing code snippets and diagrams where applicable.

# %% [markdown]
# ### Task 1: **Dependency analysis**
# The Pandas has a set of Primary and Optional dependencies which it works. The following is the exhaustive dependecy list that pandas requires.

# %%
import pandas as pd
print(pd.show_versions())
# Out:
# /usr/local/lib/python3.10/dist-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# INSTALLED VERSIONS
# ------------------
# commit           : 0f437949513225922d851e9581723d82120684a6
# python           : 3.10.12.final.0
# python-bits      : 64
# OS               : Linux
# OS-release       : 6.1.85+
# Version          : #1 SMP PREEMPT_DYNAMIC Sun Apr 28 14:29:16 UTC 2024
# machine          : x86_64
# processor        : x86_64
# byteorder        : little
# LC_ALL           : en_US.UTF-8
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 2.0.3
# numpy            : 1.25.2
# pytz             : 2023.4
# dateutil         : 2.8.2
# setuptools       : 67.7.2
# pip              : 23.1.2
# Cython           : 3.0.10
# pytest           : 7.4.4
# hypothesis       : None
# sphinx           : 5.0.2
# blosc            : None
# feather          : None
# xlsxwriter       : None
# lxml.etree       : 4.9.4
# html5lib         : 1.1
# pymysql          : None
# psycopg2         : 2.9.9
# jinja2           : 3.1.4
# IPython          : 7.34.0
# pandas_datareader: 0.10.0
# bs4              : 4.12.3
# bottleneck       : None
# brotli           : None
# fastparquet      : None
# fsspec           : 2023.6.0
# gcsfs            : 2023.6.0
# matplotlib       : 3.7.1
# numba            : 0.58.1
# numexpr          : 2.10.0
# odfpy            : None
# openpyxl         : 3.1.2
# pandas_gbq       : 0.19.2
# pyarrow          : 14.0.2
# pyreadstat       : None
# pyxlsb           : None
# s3fs             : None
# scipy            : 1.11.4
# snappy           : None
# sqlalchemy       : 2.0.30
# tables           : 3.8.0
# tabulate         : 0.9.0
# xarray           : 2023.7.0
# xlrd             : 2.0.1
# zstandard        : None
# tzdata           : 2024.1
# qtpy             : None
# pyqt5            : None
# None

# %% [markdown]
# Out of these, the following primary dependencies would be used will be selected for our research on unsafe modules.
#
# #### Libraries selected are:
#
# *   **Numpy** due to its data manipulation requirements
# *   **bs4** since this this module works parsed external content
# *   **pymysql** & **sqlalchemy** since these works with db hosted locally or public ones.
# *   **fsspec** since this library works with filesystem operations

# %% [markdown]
# #### Unsafe Operations:
# The Unsafe operations in python covers a wide range of operations and method that maybe secure in concerns on improper use or that which may affect the normal code functions. In this assignment, we will look into the latter and focus on these low-level modules that will could be used for such operations.
#
# ##### **System Operations :**
#   * os :
#         'system', 'popen', 'spawn', 'execv', 'execl'
#   * sys :
#         'exit', 'setrecursionlimit', 'settrace'
#   * subprocess:
#         'call', 'Popen', 'run'
#   * pickle :
#         'load', 'loads', 'Unpickler'
#   * shutil :
#         rmtree
#
# ##### **WebAccess :**
# Since the problem statement mentions the need for webaccess, these modules will also be analyzed for safe operations:
#   * socket :
#         'socket', 'create_connection', 'getaddrinfo', 'gethostbyname',
#         'gethostbyname_ex', 'gethostbyaddr', 'create_server', 'fromfd'
#   * requests :
#           'get', 'post', 'put', 'delete', 'head', 'options', 'patch', 'Session'
#   * ftplib

# %% [markdown]
# ### Task 2: **Code Analysis**
# The Code analyis includes on how to call put the possibly unsafe operations in the pandas library and its dependencies
#
# **Method 1:**
#
# The main pandas library and its dependency list could be searched using the as walk feature to identify a limited set of harmful operations which we have filtered out.

# %%
import ast
def analyze_file(filepath):
    with open(filepath, 'r', encoding='utf-8') as file:
        try:
            tree = ast.parse(file.read(), filename=filepath)
        except SyntaxError:
            return []

    unsafe_calls = []

    class UnsafeCallVisitor(ast.NodeVisitor):
        def visit_Import(self, node):
            for alias in node.names:
                if alias.name in UNSAFE_MODULES:
                    unsafe_calls.append((alias.name, node.lineno))
            self.generic_visit(node)

        def visit_ImportFrom(self, node):
            if node.module in UNSAFE_MODULES:
                unsafe_calls.append((node.module, node.lineno))
            self.generic_visit(node)

        def visit_Call(self, node):
            if isinstance(node.func, ast.Attribute):
                module_name = node.func.value.id if isinstance(node.func.value, ast.Name) else None
                func_name = node.func.attr
                if module_name in UNSAFE_MODULES and (func_name in UNSAFE_MODULES[module_name] or not UNSAFE_MODULES[module_name]):
                    unsafe_calls.append((f"{module_name}.{func_name}", node.lineno))
            self.generic_visit(node)

    visitor = UnsafeCallVisitor()
    visitor.visit(tree)

    return unsafe_calls

# %%
import os

# List of potentially unsafe modules and their functions
UNSAFE_MODULES = {
    'os': ['system', 'popen', 'spawn', 'execv', 'execl'],
    'sys': ['exit', 'setrecursionlimit', 'settrace'],
    'subprocess': ['call', 'Popen', 'run'],
    'shutil': ['rmtree'],
    'socket': [],
    'requests': [],
    'ftplib': [],
    'pickle': ['load', 'loads', 'Unpickler']
}


def analyze_directory(directory):
    unsafe_operations = {}
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.py'):
                filepath = os.path.join(root, file)
                unsafe_calls = analyze_file(filepath)
                if unsafe_calls:
                    unsafe_operations[filepath] = unsafe_calls
    return unsafe_operations

def generate_report(unsafe_operations):
    report = []
    for filepath, operations in unsafe_operations.items():
        report.append(f"File: {filepath}")
        for op in operations:
            report.append(f"  Line {op[1]}: {op[0]}")
    return "\n".join(report)

if __name__ == "__main__":
    directory_to_analyze = '/usr/local/lib/python3.10/dist-packages/pandas'
    unsafe_operations = analyze_directory(directory_to_analyze)
    report = generate_report(unsafe_operations)
    print(report)
# Out:
# File: /usr/local/lib/python3.10/dist-packages/pandas/_typing.py
#   Line 8: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/conftest.py
#   Line 32: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/_testing/_warnings.py
#   Line 8: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/_testing/contexts.py
#   Line 4: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/_testing/_io.py
#   Line 7: socket
# File: /usr/local/lib/python3.10/dist-packages/pandas/_testing/__init__.py
#   Line 7: os
#   Line 10: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/io/pickle.py
#   Line 4: pickle
#   Line 196: pickle.load
# File: /usr/local/lib/python3.10/dist-packages/pandas/io/stata.py
#   Line 17: os
#   Line 19: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/io/pytables.py
#   Line 14: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/io/parquet.py
#   Line 5: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/io/common.py
#   Line 22: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/io/formats/printing.py
#   Line 6: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py
#   Line 8: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py
#   Line 17: shutil
# File: /usr/local/lib/python3.10/dist-packages/pandas/io/formats/string.py
#   Line 6: shutil
# File: /usr/local/lib/python3.10/dist-packages/pandas/io/formats/console.py
#   Line 6: shutil
# File: /usr/local/lib/python3.10/dist-packages/pandas/io/formats/info.py
#   Line 7: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/io/json/_normalize.py
#   Line 10: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/io/sas/sas7bdat.py
#   Line 23: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/io/clipboard/__init__.py
#   Line 56: os
#   Line 58: shutil
#   Line 59: subprocess
#   Line 91: subprocess.call
#   Line 111: subprocess.Popen
#   Line 117: subprocess.Popen
#   Line 183: subprocess.Popen
#   Line 192: subprocess.Popen
#   Line 214: subprocess.Popen
#   Line 223: subprocess.Popen
#   Line 235: subprocess.Popen
#   Line 249: subprocess.Popen
#   Line 491: subprocess.Popen
#   Line 495: subprocess.Popen
# File: /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/python_parser.py
#   Line 10: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py
#   Line 10: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py
#   Line 7: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/compat/_optional.py
#   Line 4: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/compat/pickle_compat.py
#   Line 9: pickle
# File: /usr/local/lib/python3.10/dist-packages/pandas/compat/__init__.py
#   Line 12: os
#   Line 14: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/compat/compressors.py
#   Line 8: pickle
# File: /usr/local/lib/python3.10/dist-packages/pandas/compat/_constants.py
#   Line 11: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/core/config_init.py
#   Line 14: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py
#   Line 4: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py
#   Line 10: pickle
# File: /usr/local/lib/python3.10/dist-packages/pandas/core/series.py
#   Line 6: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py
#   Line 19: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/core/arrays/categorical.py
#   Line 6: shutil
# File: /usr/local/lib/python3.10/dist-packages/pandas/core/arrays/arrow/array.py
#   Line 7: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/multi.py
#   Line 4: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py
#   Line 5: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/core/computation/scope.py
#   Line 12: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py
#   Line 7: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/core/strings/object_array.py
#   Line 5: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/_config/display.py
#   Line 8: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/_config/localization.py
#   Line 12: subprocess
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/test_downstream.py
#   Line 5: subprocess
#   Line 6: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/test_optional_dependency.py
#   Line 1: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/arrays/string_/test_string_arrow.py
#   Line 1: pickle
#   Line 212: pickle.loads
#   Line 215: pickle.loads
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/arrays/categorical/test_analytics.py
#   Line 2: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/scalar/test_na_scalar.py
#   Line 6: pickle
#   Line 298: pickle.loads
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/config/test_localization.py
#   Line 3: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/frame/methods/test_to_csv.py
#   Line 3: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/base/test_misc.py
#   Line 1: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/base/test_constructors.py
#   Line 2: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/reshape/test_qcut.py
#   Line 1: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/series/methods/test_astype.py
#   Line 7: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/test_s3.py
#   Line 2: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/test_user_agent.py
#   Line 8: socket
#   Line 219: socket.socket
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/test_orc.py
#   Line 5: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/test_compression.py
#   Line 3: os
#   Line 5: subprocess
#   Line 6: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/test_parquet.py
#   Line 4: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/test_html.py
#   Line 7: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/conftest.py
#   Line 1: os
#   Line 3: subprocess
#   Line 96: subprocess.Popen
#   Line 105: requests.get
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/test_gcs.py
#   Line 2: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/test_pickle.py
#   Line 21: os
#   Line 23: pickle
#   Line 24: shutil
#   Line 182: pickle.load
#   Line 587: pickle.load
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/generate_legacy_storage_files.py
#   Line 36: os
#   Line 37: pickle
#   Line 39: sys
#   Line 326: sys.exit
#   Line 337: sys.exit
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/test_stata.py
#   Line 6: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/test_clipboard.py
#   Line 1: os
#   Line 2: subprocess
#   Line 419: subprocess.run
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/test_common.py
#   Line 13: os
#   Line 15: pickle
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/formats/test_info.py
#   Line 4: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/formats/test_to_csv.py
#   Line 2: os
#   Line 3: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/formats/test_format.py
#   Line 16: shutil
#   Line 17: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/parser/test_unsupported.py
#   Line 10: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/parser/test_compression.py
#   Line 6: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/parser/test_c_parser_only.py
#   Line 14: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/parser/conftest.py
#   Line 3: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/parser/test_encoding.py
#   Line 9: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/parser/common/test_common_basic.py
#   Line 8: os
#   Line 10: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/parser/common/test_index.py
#   Line 7: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/parser/common/test_file_buffer_url.py
#   Line 9: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/parser/common/test_read_errors.py
#   Line 8: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/parser/dtypes/test_categorical.py
#   Line 6: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/json/test_pandas.py
#   Line 6: os
#   Line 7: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/sas/test_sas7bdat.py
#   Line 4: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/pytables/test_file_handling.py
#   Line 1: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/pytables/test_store.py
#   Line 3: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/xml/test_to_xml.py
#   Line 7: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/xml/test_xml.py
#   Line 8: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/excel/test_writers.py
#   Line 8: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/io/excel/test_readers.py
#   Line 6: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/window/test_cython_aggregations.py
#   Line 2: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/util/test_safe_import.py
#   Line 1: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/util/test_show_versions.py
#   Line 2: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/util/test_util.py
#   Line 1: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/util/test_str_methods.py
#   Line 1: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/extension/test_arrow.py
#   Line 25: pickle
#   Line 1681: pickle.loads
#   Line 1684: pickle.loads
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/extension/json/array.py
#   Line 24: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/extension/json/test_json.py
#   Line 3: sys
#   Line 170: sys.setrecursionlimit
#   Line 173: sys.setrecursionlimit
#   Line 181: sys.setrecursionlimit
#   Line 184: sys.setrecursionlimit
#   Line 192: sys.setrecursionlimit
#   Line 195: sys.setrecursionlimit
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/extension/decimal/array.py
#   Line 6: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/plotting/test_converter.py
#   Line 5: subprocess
#   Line 6: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/plotting/test_backend.py
#   Line 1: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/plotting/test_datetimelike.py
#   Line 8: pickle
# File: /usr/local/lib/python3.10/dist-packages/pandas/tests/dtypes/test_inference.py
#   Line 20: sys
#   Line 217: sys.setrecursionlimit
#   Line 221: sys.setrecursionlimit
# File: /usr/local/lib/python3.10/dist-packages/pandas/util/_test_decorators.py
#   Line 79: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/util/_print_versions.py
#   Line 6: os
#   Line 9: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/util/_exceptions.py
#   Line 5: os
# File: /usr/local/lib/python3.10/dist-packages/pandas/util/_str_methods.py
#   Line 11: sys
# File: /usr/local/lib/python3.10/dist-packages/pandas/util/_tester.py
#   Line 6: os
#   Line 7: sys
#   Line 35: sys.exit

# %% [markdown]
# Now, analysing the filtered dependency list for unsafe operations

# %%
import os
import ast
import sys
import pkg_resources

# Increase the recursion limit
sys.setrecursionlimit(3000)

# List of potentially unsafe modules and their functions
UNSAFE_MODULES = {
    'os': ['system', 'popen', 'spawn', 'execv', 'execl'],
    'sys': ['exit', 'setrecursionlimit', 'settrace'],
    'subprocess': ['call', 'Popen', 'run'],
    'shutil': ['rmtree'],
    'socket': [
        'socket', 'create_connection', 'getaddrinfo', 'gethostbyname',
        'gethostbyname_ex', 'gethostbyaddr', 'create_server', 'fromfd'
    ],
    'requests': [
        'get', 'post', 'put', 'delete', 'head', 'options', 'patch', 'Session'
    ],
    'ftplib': [],
    'pickle': ['load', 'loads', 'Unpickler']
}

def analyze_file(filepath):
    encodings = ['utf-8', 'latin-1', 'iso-8859-1']
    for encoding in encodings:
        try:
            with open(filepath, 'r', encoding=encoding) as file:
                try:
                    tree = ast.parse(file.read(), filename=filepath)
                except SyntaxError:
                    return []
            break
        except (UnicodeDecodeError, FileNotFoundError):
            continue
    unsafe_calls = []

    class UnsafeCallVisitor(ast.NodeVisitor):
        def visit_Import(self, node):
            for alias in node.names:
                if alias.name in UNSAFE_MODULES:
                    unsafe_calls.append((alias.name, node.lineno))
            self.generic_visit(node)

        def visit_ImportFrom(self, node):
            if node.module in UNSAFE_MODULES:
                unsafe_calls.append((node.module, node.lineno))
            self.generic_visit(node)

        def visit_Call(self, node):
            if isinstance(node.func, ast.Attribute):
                module_name = node.func.value.id if isinstance(node.func.value, ast.Name) else None
                func_name = node.func.attr
                if module_name in UNSAFE_MODULES and (func_name in UNSAFE_MODULES[module_name] or not UNSAFE_MODULES[module_name]):
                    unsafe_calls.append((f"{module_name}.{func_name}", node.lineno))
            self.generic_visit(node)

    visitor = UnsafeCallVisitor()
    visitor.visit(tree)

    return unsafe_calls

def analyze_directory(directory):
    unsafe_operations = {}
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.py'):
                filepath = os.path.join(root, file)
                unsafe_calls = analyze_file(filepath)
                if unsafe_calls:
                    unsafe_operations[filepath] = unsafe_calls
    return unsafe_operations

def generate_report(unsafe_operations):
    report = []
    for filepath, operations in unsafe_operations.items():
        report.append(f"File: {filepath}")
        for op in operations:
            report.append(f"  Line {op[1]}: {op[0]}")
    return "\n".join(report)

def get_dependency_directories():
    dependency_dirs = []
    for dist in pkg_resources.working_set:
        if dist.project_name in DEPENDENCIES:
            try:
                dependency_dirs.append(dist.location)
            except KeyError:
                continue
    return dependency_dirs

if __name__ == "__main__":
    DEPENDENCIES = [
        'numpy', 'pymysql','bs4', 'fsspec',
        'sqlalchemy'
    ]

    unsafe_operations = {}
    for directory in get_dependency_directories():
        module_operations = analyze_directory(directory)
        unsafe_operations.update(module_operations)

    report = generate_report(unsafe_operations)
    print(report)
# Out:
# File: /usr/local/lib/python3.10/dist-packages/socks.py
#   Line 10: os
#   Line 11: os
#   Line 12: socket
#   Line 14: sys
#   Line 180: socket.getaddrinfo
#   Line 573: socket.getaddrinfo
#   Line 622: socket.gethostbyname
#   Line 671: socket.gethostbyname
#   Line 750: socket.gethostbyname
# File: /usr/local/lib/python3.10/dist-packages/portpicker.py
#   Line 41: os
#   Line 43: socket
#   Line 44: sys
#   Line 113: socket.socket
#   Line 236: socket.socket
#   Line 239: socket.socket
#   Line 331: sys.exit
# File: /usr/local/lib/python3.10/dist-packages/nest_asyncio.py
#   Line 5: os
#   Line 6: sys
# File: /usr/local/lib/python3.10/dist-packages/entrypoints.py
#   Line 12: sys
# File: /usr/local/lib/python3.10/dist-packages/pwiz.py
#   Line 4: os
#   Line 5: sys
#   Line 47: sys.exit
#   Line 208: sys.exit
# File: /usr/local/lib/python3.10/dist-packages/ipykernel_launcher.py
#   Line 7: sys
# File: /usr/local/lib/python3.10/dist-packages/appdirs.py
#   Line 20: sys
#   Line 21: os
# File: /usr/local/lib/python3.10/dist-packages/pydot.py
#   Line 7: os
#   Line 9: subprocess
#   Line 10: sys
#   Line 132: subprocess.Popen
# File: /usr/local/lib/python3.10/dist-packages/typing_extensions.py
#   Line 7: sys
# File: /usr/local/lib/python3.10/dist-packages/colour.py
#   Line 41: sys
# File: /usr/local/lib/python3.10/dist-packages/six.py
#   Line 28: sys
# File: /usr/local/lib/python3.10/dist-packages/imagesize.py
#   Line 2: os
# File: /usr/local/lib/python3.10/dist-packages/pandocfilters.py
#   Line 14: os
#   Line 15: sys
#   Line 17: shutil
#   Line 46: shutil.rmtree
# File: /usr/local/lib/python3.10/dist-packages/dot_parser.py
#   Line 12: sys
# File: /usr/local/lib/python3.10/dist-packages/decorator.py
#   Line 37: sys
# File: /usr/local/lib/python3.10/dist-packages/pathlib.py
#   Line 5: os
#   Line 8: sys
# File: /usr/local/lib/python3.10/dist-packages/soundfile.py
#   Line 13: os
#   Line 14: sys
#   Line 15: os
# File: /usr/local/lib/python3.10/dist-packages/peewee.py
#   Line 16: socket
#   Line 18: sys
# File: /usr/local/lib/python3.10/dist-packages/httpimport.py
#   Line 6: os
#   Line 9: sys
# File: /usr/local/lib/python3.10/dist-packages/pickleshare.py
#   Line 47: os
#   Line 55: pickle
#   Line 57: sys
#   Line 102: pickle.loads
#   Line 322: sys
# File: /usr/local/lib/python3.10/dist-packages/threadpoolctl.py
#   Line 14: os
#   Line 16: sys
#   Line 1246: sys
# File: /usr/local/lib/python3.10/dist-packages/py.py
#   Line 4: sys
# File: /usr/local/lib/python3.10/dist-packages/shapefile.py
#   Line 12: os
#   Line 13: sys
#   Line 2671: sys.exit
# File: /usr/local/lib/python3.10/dist-packages/cython.py
#   Line 9: os
#   Line 10: sys
# File: /usr/local/lib/python3.10/dist-packages/sockshandler.py
#   Line 10: socket
#   Line 104: sys
# File: /usr/local/lib/python3.10/dist-packages/isympy.py
#   Line 170: os
#   Line 171: sys
# File: /usr/local/lib/python3.10/dist-packages/pbr/version.py
#   Line 23: sys
# File: /usr/local/lib/python3.10/dist-packages/pbr/find_package.py
#   Line 16: os
# File: /usr/local/lib/python3.10/dist-packages/pbr/core.py
#   Line 47: os
#   Line 48: sys
# File: /usr/local/lib/python3.10/dist-packages/pbr/testr_command.py
#   Line 46: os
#   Line 47: sys
#   Line 142: os.system
#   Line 143: os.system
#   Line 144: os.system
# File: /usr/local/lib/python3.10/dist-packages/pbr/git.py
#   Line 23: os
#   Line 25: subprocess
#   Line 46: subprocess.Popen
# File: /usr/local/lib/python3.10/dist-packages/pbr/extra_files.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/pbr/packaging.py
#   Line 37: os
#   Line 39: sys
# File: /usr/local/lib/python3.10/dist-packages/pbr/util.py
#   Line 66: os
#   Line 69: sys
#   Line 269: sys.exit
# File: /usr/local/lib/python3.10/dist-packages/pbr/options.py
#   Line 44: os
# File: /usr/local/lib/python3.10/dist-packages/pbr/cmd/main.py
#   Line 18: sys
#   Line 119: sys.exit
# File: /usr/local/lib/python3.10/dist-packages/pbr/hooks/files.py
#   Line 16: os
#   Line 18: sys
# File: /usr/local/lib/python3.10/dist-packages/pbr/hooks/commands.py
#   Line 16: os
# File: /usr/local/lib/python3.10/dist-packages/pbr/tests/test_hooks.py
#   Line 41: os
# File: /usr/local/lib/python3.10/dist-packages/pbr/tests/test_util.py
#   Line 22: sys
# File: /usr/local/lib/python3.10/dist-packages/pbr/tests/test_packaging.py
#   Line 43: os
# File: /usr/local/lib/python3.10/dist-packages/pbr/tests/test_core.py
#   Line 42: os
#   Line 43: sys
# File: /usr/local/lib/python3.10/dist-packages/pbr/tests/test_files.py
#   Line 18: os
# File: /usr/local/lib/python3.10/dist-packages/pbr/tests/base.py
#   Line 42: os
#   Line 43: shutil
#   Line 44: subprocess
#   Line 45: sys
#   Line 182: subprocess.Popen
#   Line 206: subprocess.Popen
# File: /usr/local/lib/python3.10/dist-packages/pbr/tests/test_wsgi.py
#   Line 15: os
#   Line 17: subprocess
#   Line 18: sys
#   Line 87: subprocess.Popen
# File: /usr/local/lib/python3.10/dist-packages/pbr/tests/test_integration.py
#   Line 21: sys
# File: /usr/local/lib/python3.10/dist-packages/pbr/tests/util.py
#   Line 42: os
#   Line 43: shutil
#   Line 45: sys
#   Line 78: shutil.rmtree
# File: /usr/local/lib/python3.10/dist-packages/pbr/tests/test_setup.py
#   Line 19: os
# File: /usr/local/lib/python3.10/dist-packages/pbr/tests/__init__.py
#   Line 14: os
# File: /usr/local/lib/python3.10/dist-packages/pbr/tests/testpackage/pbr_testpackage/wsgi.py
#   Line 19: sys
# File: /usr/local/lib/python3.10/dist-packages/stevedore/_cache.py
#   Line 22: os
#   Line 25: sys
# File: /usr/local/lib/python3.10/dist-packages/stevedore/tests/test_cache.py
#   Line 15: sys
# File: /usr/local/lib/python3.10/dist-packages/bandit/cli/main.py
#   Line 9: os
#   Line 10: sys
#   Line 66: sys.exit
#   Line 457: sys.exit
#   Line 597: sys.exit
#   Line 617: sys.exit
#   Line 636: sys.exit
#   Line 643: sys.exit
#   Line 661: sys.exit
#   Line 684: sys.exit
#   Line 686: sys.exit
# File: /usr/local/lib/python3.10/dist-packages/bandit/cli/config_generator.py
#   Line 8: os
#   Line 9: sys
#   Line 152: sys.exit
#   Line 204: sys.exit
# File: /usr/local/lib/python3.10/dist-packages/bandit/cli/baseline.py
#   Line 16: os
#   Line 17: shutil
#   Line 18: subprocess
#   Line 19: sys
#   Line 55: sys.exit
#   Line 69: sys.exit
#   Line 72: sys.exit
#   Line 130: sys.exit
#   Line 139: shutil.rmtree
# File: /usr/local/lib/python3.10/dist-packages/bandit/blacklists/calls.py
#   Line 324: sys
# File: /usr/local/lib/python3.10/dist-packages/bandit/core/manager.py
#   Line 10: os
#   Line 12: sys
#   Line 326: sys.exit
# File: /usr/local/lib/python3.10/dist-packages/bandit/core/utils.py
#   Line 8: sys
# File: /usr/local/lib/python3.10/dist-packages/bandit/core/config.py
#   Line 6: sys
# File: /usr/local/lib/python3.10/dist-packages/bandit/core/extension_loader.py
#   Line 3: sys
# File: /usr/local/lib/python3.10/dist-packages/bandit/plugins/hashlib_insecure_functions.py
#   Line 51: sys
# File: /usr/local/lib/python3.10/dist-packages/bandit/formatters/csv.py
#   Line 34: sys
# File: /usr/local/lib/python3.10/dist-packages/bandit/formatters/screen.py
#   Line 37: sys
# File: /usr/local/lib/python3.10/dist-packages/bandit/formatters/json.py
#   Line 82: sys
# File: /usr/local/lib/python3.10/dist-packages/bandit/formatters/xml.py
#   Line 37: sys
# File: /usr/local/lib/python3.10/dist-packages/bandit/formatters/sarif.py
#   Line 130: sys
# File: /usr/local/lib/python3.10/dist-packages/bandit/formatters/yaml.py
#   Line 67: sys
# File: /usr/local/lib/python3.10/dist-packages/bandit/formatters/custom.py
#   Line 29: os
#   Line 32: sys
#   Line 99: sys.exit
#   Line 104: sys.exit
# File: /usr/local/lib/python3.10/dist-packages/bandit/formatters/text.py
#   Line 37: sys
# File: /usr/local/lib/python3.10/dist-packages/bandit/formatters/html.py
#   Line 150: sys
# File: /usr/local/lib/python3.10/dist-packages/google/api_core/rest_streaming.py
#   Line 21: requests
# File: /usr/local/lib/python3.10/dist-packages/google/api_core/operations_v1/abstract_operations_client.py
#   Line 18: os
# File: /usr/local/lib/python3.10/dist-packages/google/api_core/operations_v1/transports/rest.py
#   Line 20: requests
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/text_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/text_service/transports/rest.py
#   Line 31: requests
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/model_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/model_service/transports/rest.py
#   Line 37: requests
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py
#   Line 31: requests
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/permission_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/permission_service/transports/rest.py
#   Line 31: requests
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/file_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/file_service/transports/rest.py
#   Line 31: requests
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/retriever_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/retriever_service/transports/rest.py
#   Line 31: requests
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/discuss_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/discuss_service/transports/rest.py
#   Line 31: requests
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta2/services/text_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta2/services/text_service/transports/rest.py
#   Line 31: requests
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta2/services/model_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta2/services/model_service/transports/rest.py
#   Line 31: requests
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta2/services/discuss_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta2/services/discuss_service/transports/rest.py
#   Line 31: requests
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta3/services/text_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta3/services/text_service/transports/rest.py
#   Line 31: requests
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta3/services/model_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta3/services/model_service/transports/rest.py
#   Line 37: requests
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta3/services/permission_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta3/services/permission_service/transports/rest.py
#   Line 31: requests
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta3/services/discuss_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta3/services/discuss_service/transports/rest.py
#   Line 31: requests
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1/services/model_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1/services/model_service/transports/rest.py
#   Line 31: requests
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1/services/generative_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1/services/generative_service/transports/rest.py
#   Line 31: requests
# File: /usr/local/lib/python3.10/dist-packages/google/protobuf/descriptor.py
#   Line 46: os
# File: /usr/local/lib/python3.10/dist-packages/google/protobuf/json_format.py
#   Line 52: sys
# File: /usr/local/lib/python3.10/dist-packages/google/protobuf/proto_builder.py
#   Line 35: os
# File: /usr/local/lib/python3.10/dist-packages/google/protobuf/internal/python_message.py
#   Line 55: sys
# File: /usr/local/lib/python3.10/dist-packages/google/protobuf/internal/api_implementation.py
#   Line 34: os
#   Line 35: sys
# File: /usr/local/lib/python3.10/dist-packages/google/protobuf/internal/containers.py
#   Line 45: pickle
# File: /usr/local/lib/python3.10/dist-packages/google/resumable_media/_upload.py
#   Line 26: os
#   Line 29: sys
# File: /usr/local/lib/python3.10/dist-packages/google/oauth2/_reauth_async.py
#   Line 35: sys
# File: /usr/local/lib/python3.10/dist-packages/google/oauth2/reauth.py
#   Line 35: sys
# File: /usr/local/lib/python3.10/dist-packages/google/oauth2/id_token.py
#   Line 60: os
# File: /usr/local/lib/python3.10/dist-packages/google/oauth2/_id_token_async.py
#   Line 63: os
# File: /usr/local/lib/python3.10/dist-packages/google/oauth2/challenges.py
#   Line 21: sys
# File: /usr/local/lib/python3.10/dist-packages/google/oauth2/__init__.py
#   Line 17: sys
# File: /usr/local/lib/python3.10/dist-packages/google/auth/credentials.py
#   Line 20: os
# File: /usr/local/lib/python3.10/dist-packages/google/auth/_helpers.py
#   Line 21: sys
# File: /usr/local/lib/python3.10/dist-packages/google/auth/_cloud_sdk.py
#   Line 17: os
#   Line 18: subprocess
# File: /usr/local/lib/python3.10/dist-packages/google/auth/identity_pool.py
#   Line 43: os
# File: /usr/local/lib/python3.10/dist-packages/google/auth/_default_async.py
#   Line 22: os
# File: /usr/local/lib/python3.10/dist-packages/google/auth/_default.py
#   Line 23: os
# File: /usr/local/lib/python3.10/dist-packages/google/auth/pluggable.py
#   Line 39: os
#   Line 40: subprocess
#   Line 41: sys
#   Line 214: subprocess.run
#   Line 267: subprocess.run
# File: /usr/local/lib/python3.10/dist-packages/google/auth/aws.py
#   Line 44: os
# File: /usr/local/lib/python3.10/dist-packages/google/auth/__init__.py
#   Line 18: sys
# File: /usr/local/lib/python3.10/dist-packages/google/auth/transport/_custom_tls_signer.py
#   Line 23: os
#   Line 24: sys
# File: /usr/local/lib/python3.10/dist-packages/google/auth/transport/urllib3.py
#   Line 20: os
# File: /usr/local/lib/python3.10/dist-packages/google/auth/transport/requests.py
#   Line 22: os
#   Line 26: requests
#   Line 141: requests.Session
#   Line 404: requests.Session
# File: /usr/local/lib/python3.10/dist-packages/google/auth/transport/grpc.py
#   Line 20: os
# File: /usr/local/lib/python3.10/dist-packages/google/auth/transport/_mtls_helper.py
#   Line 19: os
#   Line 21: subprocess
#   Line 105: subprocess.Popen
# File: /usr/local/lib/python3.10/dist-packages/google/auth/transport/_http_client.py
#   Line 19: socket
# File: /usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/_metadata.py
#   Line 24: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/_helpers/__init__.py
#   Line 25: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery_storage_v1/gapic_types.py
#   Line 21: sys
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery_storage_v1/services/big_query_write/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery_storage_v1/services/big_query_read/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery_connection_v1/services/connection_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery_connection_v1/services/connection_service/transports/rest.py
#   Line 31: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/language_v1/services/language_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/language_v1/services/language_service/transports/rest.py
#   Line 31: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/pipeline_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/pipeline_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/persistent_resource_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/persistent_resource_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/match_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/match_service/transports/rest.py
#   Line 33: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/gen_ai_tuning_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/gen_ai_tuning_service/transports/rest.py
#   Line 33: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/model_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/model_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/prediction_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/prediction_service/transports/rest.py
#   Line 33: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/dataset_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/dataset_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/featurestore_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/featurestore_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/featurestore_online_serving_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/featurestore_online_serving_service/transports/rest.py
#   Line 33: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/tensorboard_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/tensorboard_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/notebook_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/notebook_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/migration_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/migration_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/schedule_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/schedule_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/index_endpoint_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/index_endpoint_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/endpoint_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/endpoint_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/specialist_pool_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/specialist_pool_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/feature_online_store_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/feature_online_store_service/transports/rest.py
#   Line 33: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/deployment_resource_pool_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/deployment_resource_pool_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/index_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/index_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/feature_online_store_admin_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/feature_online_store_admin_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/metadata_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/metadata_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/llm_utility_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/llm_utility_service/transports/rest.py
#   Line 33: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/vizier_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/vizier_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/feature_registry_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/feature_registry_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/job_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/job_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/model_garden_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/model_garden_service/transports/rest.py
#   Line 33: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/translate_v3/services/translation_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/translate_v3/services/translation_service/transports/rest.py
#   Line 31: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/datastore_admin_v1/services/datastore_admin/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/datastore_admin_v1/services/datastore_admin/transports/rest.py
#   Line 32: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/storage/transfer_manager.py
#   Line 21: os
#   Line 23: pickle
#   Line 853: pickle.loads
#   Line 873: pickle.loads
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/storage/batch.py
#   Line 26: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/storage/_helpers.py
#   Line 22: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/storage/blob.py
#   Line 27: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/storage/retry.py
#   Line 20: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/client/__init__.py
#   Line 19: os
#   Line 20: pickle
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/_testing/__init__.py
#   Line 41: os
#   Line 51: os
#   Line 58: shutil
#   Line 65: shutil.rmtree
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery/_helpers.py
#   Line 23: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery/_tqdm_helpers.py
#   Line 18: sys
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery/_job_helpers.py
#   Line 40: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery/client.py
#   Line 29: os
#   Line 134: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery/job/query.py
#   Line 26: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery/magics/magics.py
#   Line 89: sys
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/functions_v2/services/function_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/functions_v2/services/function_service/transports/rest.py
#   Line 40: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/_http/__init__.py
#   Line 20: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/language_v2/services/language_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/language_v2/services/language_service/transports/rest.py
#   Line 31: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/models.py
#   Line 20: shutil
#   Line 22: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/base.py
#   Line 25: sys
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/initializer.py
#   Line 22: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/tensorboard/logdir_loader.py
#   Line 21: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/tensorboard/upload_tracker.py
#   Line 22: sys
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/tensorboard/uploader.py
#   Line 23: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/tensorboard/plugins/tf_profiler/profile_uploader.py
#   Line 22: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/vertex_ray/bigquery_datasink.py
#   Line 20: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/vertex_ray/__init__.py
#   Line 19: sys
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/vertex_ray/bigquery_datasource.py
#   Line 19: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/vertex_ray/predict/tensorflow/register.py
#   Line 19: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/vertex_ray/predict/xgboost/register.py
#   Line 21: os
#   Line 22: pickle
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/vertex_ray/predict/sklearn/register.py
#   Line 21: os
#   Line 22: pickle
#   Line 153: pickle.load
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/vertex_ray/predict/torch/register.py
#   Line 19: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/explain/lit.py
#   Line 18: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/utils/source_utils.py
#   Line 19: os
#   Line 21: shutil
#   Line 22: subprocess
#   Line 23: sys
#   Line 175: shutil.rmtree
#   Line 191: subprocess.Popen
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/utils/gcs_utils.py
#   Line 21: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/utils/_ipython_utils.py
#   Line 18: sys
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/utils/prediction_utils.py
#   Line 18: shutil
#   Line 21: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/prediction/model_server.py
#   Line 21: os
#   Line 22: sys
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/prediction/local_endpoint.py
#   Line 20: requests
#   Line 392: requests.post
#   Line 397: requests.post
#   Line 425: requests.get
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/prediction/xgboost/predictor.py
#   Line 20: os
#   Line 21: pickle
#   Line 62: pickle.load
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/prediction/sklearn/predictor.py
#   Line 20: os
#   Line 21: pickle
#   Line 49: pickle.load
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/metadata/_models.py
#   Line 19: os
#   Line 20: pickle
#   Line 152: pickle.load
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/metadata/metadata.py
#   Line 20: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/docker_utils/run.py
#   Line 19: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/docker_utils/build.py
#   Line 20: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/docker_utils/local_util.py
#   Line 20: subprocess
#   Line 45: subprocess.Popen
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/preview/vertex_ray/__init__.py
#   Line 19: sys
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/training_utils/environment_variables.py
#   Line 21: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/training_utils/cloud_profiler/webserver.py
#   Line 20: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/training_utils/cloud_profiler/plugins/tensorflow/tensorboard_api.py
#   Line 20: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/datastore_v1/services/datastore/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/datastore_v1/services/datastore/transports/rest.py
#   Line 31: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/translate_v3beta1/services/translation_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/translate_v3beta1/services/translation_service/transports/rest.py
#   Line 31: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/firestore_v1/base_client.py
#   Line 27: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/firestore_v1/services/firestore/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/firestore_v1/services/firestore/transports/rest.py
#   Line 32: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/iam_v2/services/policies/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/iam_v2/services/policies/transports/rest.py
#   Line 37: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/extension_execution_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/extension_execution_service/transports/rest.py
#   Line 33: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/pipeline_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/pipeline_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/model_monitoring_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/model_monitoring_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/reasoning_engine_execution_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/reasoning_engine_execution_service/transports/rest.py
#   Line 33: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/persistent_resource_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/persistent_resource_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/match_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/match_service/transports/rest.py
#   Line 33: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/model_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/model_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/prediction_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/prediction_service/transports/rest.py
#   Line 33: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/vertex_rag_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/vertex_rag_service/transports/rest.py
#   Line 33: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/dataset_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/dataset_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/featurestore_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/featurestore_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/featurestore_online_serving_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/featurestore_online_serving_service/transports/rest.py
#   Line 33: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/tensorboard_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/tensorboard_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/notebook_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/notebook_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/migration_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/migration_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/extension_registry_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/extension_registry_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/schedule_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/schedule_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/index_endpoint_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/index_endpoint_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/vertex_rag_data_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/vertex_rag_data_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/endpoint_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/endpoint_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/specialist_pool_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/specialist_pool_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/evaluation_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/evaluation_service/transports/rest.py
#   Line 33: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/feature_online_store_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/feature_online_store_service/transports/rest.py
#   Line 33: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/deployment_resource_pool_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/deployment_resource_pool_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/index_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/index_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/feature_online_store_admin_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/feature_online_store_admin_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/metadata_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/metadata_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/llm_utility_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/llm_utility_service/transports/rest.py
#   Line 33: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/vizier_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/vizier_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/feature_registry_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/feature_registry_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/job_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/job_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/model_garden_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/model_garden_service/transports/rest.py
#   Line 33: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/reasoning_engine_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1beta1/services/reasoning_engine_service/transports/rest.py
#   Line 34: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/functions_v1/services/cloud_functions_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/functions_v1/services/cloud_functions_service/transports/rest.py
#   Line 40: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/iam_v2beta/services/policies/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/datastore/client.py
#   Line 16: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/resourcemanager_v3/services/organizations/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/resourcemanager_v3/services/organizations/transports/rest.py
#   Line 31: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/resourcemanager_v3/services/projects/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/resourcemanager_v3/services/projects/transports/rest.py
#   Line 37: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/resourcemanager_v3/services/tag_holds/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/resourcemanager_v3/services/tag_holds/transports/rest.py
#   Line 37: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/resourcemanager_v3/services/tag_bindings/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/resourcemanager_v3/services/tag_bindings/transports/rest.py
#   Line 37: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/resourcemanager_v3/services/tag_keys/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/resourcemanager_v3/services/tag_keys/transports/rest.py
#   Line 37: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/resourcemanager_v3/services/folders/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/resourcemanager_v3/services/folders/transports/rest.py
#   Line 37: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/resourcemanager_v3/services/tag_values/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/resourcemanager_v3/services/tag_values/transports/rest.py
#   Line 37: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/firestore_admin_v1/services/firestore_admin/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/firestore_admin_v1/services/firestore_admin/transports/rest.py
#   Line 33: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery_storage_v1beta2/services/big_query_write/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery_storage_v1beta2/services/big_query_read/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/iam_credentials_v1/services/iam_credentials/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/iam_credentials_v1/services/iam_credentials/transports/rest.py
#   Line 31: requests
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/iam_admin_v1/services/iam/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/language_v1beta2/services/language_service/client.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/cloud/language_v1beta2/services/language_service/transports/rest.py
#   Line 31: requests
# File: /usr/local/lib/python3.10/dist-packages/google/_async_resumable_media/_upload.py
#   Line 26: os
#   Line 28: sys
# File: /usr/local/lib/python3.10/dist-packages/google/generativeai/discuss.py
#   Line 18: sys
# File: /usr/local/lib/python3.10/dist-packages/google/generativeai/files.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/google/generativeai/client.py
#   Line 3: os
# File: /usr/local/lib/python3.10/dist-packages/google/generativeai/types/text_types.py
#   Line 17: sys
# File: /usr/local/lib/python3.10/dist-packages/google/generativeai/types/generation_types.py
#   Line 19: sys
#   Line 24: sys
# File: /usr/local/lib/python3.10/dist-packages/google/generativeai/notebook/cmd_line_parser.py
#   Line 20: sys
# File: /usr/local/lib/python3.10/dist-packages/google/generativeai/notebook/py_utils.py
#   Line 20: sys
# File: /usr/local/lib/python3.10/dist-packages/google/colab/_import_magics.py
#   Line 35: sys
# File: /usr/local/lib/python3.10/dist-packages/google/colab/auth.py
#   Line 21: os
#   Line 23: subprocess
# File: /usr/local/lib/python3.10/dist-packages/google/colab/runtime.py
#   Line 4: os
# File: /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py
#   Line 20: os
#   Line 24: subprocess
#   Line 25: sys
#   Line 192: subprocess.Popen
# File: /usr/local/lib/python3.10/dist-packages/google/colab/drive.py
#   Line 17: os
#   Line 19: socket
#   Line 20: subprocess
#   Line 21: sys
# File: /usr/local/lib/python3.10/dist-packages/google/colab/files.py
#   Line 20: os
#   Line 22: socket
# File: /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py
#   Line 17: os
#   Line 18: sys
# File: /usr/local/lib/python3.10/dist-packages/google/colab/_pip.py
#   Line 8: os
#   Line 11: sys
# File: /usr/local/lib/python3.10/dist-packages/google/colab/_debugpy.py
#   Line 3: sys
# File: /usr/local/lib/python3.10/dist-packages/google/colab/_serverextension/_resource_monitor.py
#   Line 6: os
#   Line 7: shutil
#   Line 8: subprocess
# File: /usr/local/lib/python3.10/dist-packages/google/colab/_serverextension/_handlers.py
#   Line 17: os
#   Line 18: subprocess
# File: /usr/local/lib/python3.10/dist-packages/google/colab/_serverextension/__init__.py
#   Line 17: os
#   Line 19: subprocess
# File: /usr/local/lib/python3.10/dist-packages/google/colab/_import_hooks/_generativeai.py
#   Line 22: os
#   Line 23: sys
# File: /usr/local/lib/python3.10/dist-packages/google/colab/_import_hooks/_altair.py
#   Line 18: os
#   Line 19: sys
# File: /usr/local/lib/python3.10/dist-packages/google/colab/_import_hooks/_cv2.py
#   Line 19: os
#   Line 20: sys
# File: /usr/local/lib/python3.10/dist-packages/google/colab/_import_hooks/_pydrive2.py
#   Line 18: os
#   Line 19: sys
# File: /usr/local/lib/python3.10/dist-packages/google/colab/_import_hooks/_pydrive.py
#   Line 18: os
#   Line 19: sys
# File: /usr/local/lib/python3.10/dist-packages/google/colab/_import_hooks/_client_info.py
#   Line 18: os
#   Line 19: sys
# File: /usr/local/lib/python3.10/dist-packages/google/colab/_import_hooks/_bokeh.py
#   Line 18: os
#   Line 19: sys
# File: /usr/local/lib/python3.10/dist-packages/google/colab/output/_util.py
#   Line 17: sys
# File: /usr/local/lib/python3.10/dist-packages/google/colab/output/_tags.py
#   Line 17: sys
# File: /usr/local/lib/python3.10/dist-packages/anyio/to_process.py
#   Line 3: os
#   Line 4: pickle
#   Line 5: subprocess
#   Line 6: sys
#   Line 77: pickle.loads
#   Line 200: pickle.load
# File: /usr/local/lib/python3.10/dist-packages/anyio/lowlevel.py
#   Line 4: sys
# File: /usr/local/lib/python3.10/dist-packages/anyio/_core/_eventloop.py
#   Line 4: sys
# File: /usr/local/lib/python3.10/dist-packages/anyio/_core/_sockets.py
#   Line 3: socket
#   Line 5: sys
#   Line 7: os
#   Line 9: socket
#   Line 302: socket.socket
#   Line 363: socket.socket
# File: /usr/local/lib/python3.10/dist-packages/anyio/_core/_typedattr.py
#   Line 3: sys
# File: /usr/local/lib/python3.10/dist-packages/anyio/_core/_fileio.py
#   Line 3: os
#   Line 5: sys
#   Line 8: os
# File: /usr/local/lib/python3.10/dist-packages/anyio/_core/_subprocesses.py
#   Line 4: os
#   Line 5: subprocess
# File: /usr/local/lib/python3.10/dist-packages/anyio/streams/file.py
#   Line 4: os
# File: /usr/local/lib/python3.10/dist-packages/anyio/abc/_sockets.py
#   Line 3: socket
#   Line 8: socket
# File: /usr/local/lib/python3.10/dist-packages/anyio/abc/_tasks.py
#   Line 3: sys
# File: /usr/local/lib/python3.10/dist-packages/anyio/_backends/_trio.py
#   Line 5: socket
#   Line 11: os
# File: /usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py
# ...
# File: /usr/local/lib/python3.10/dist-packages/wheel/__main__.py
#   Line 7: sys
#   Line 19: sys.exit
#   Line 23: sys.exit
# File: /usr/local/lib/python3.10/dist-packages/wheel/vendored/packaging/_elffile.py
#   Line 12: os
# File: /usr/local/lib/python3.10/dist-packages/wheel/vendored/packaging/_manylinux.py
#   Line 4: os
#   Line 6: sys
# File: /usr/local/lib/python3.10/dist-packages/wheel/vendored/packaging/markers.py
#   Line 6: os
#   Line 8: sys
# File: /usr/local/lib/python3.10/dist-packages/wheel/vendored/packaging/_musllinux.py
#   Line 9: subprocess
#   Line 10: sys
#   Line 50: subprocess.run
# File: /usr/local/lib/python3.10/dist-packages/wheel/vendored/packaging/tags.py
#   Line 9: subprocess
#   Line 10: sys
#   Line 418: subprocess.run
# File: /usr/local/lib/python3.10/dist-packages/wheel/cli/convert.py
#   Line 5: shutil
#   Line 96: shutil.rmtree
#   Line 257: shutil.rmtree
# File: /usr/local/lib/python3.10/dist-packages/wheel/cli/__init__.py
#   Line 8: os
#   Line 9: sys
# File: /usr/local/lib/python3.10/dist-packages/wheel/cli/tags.py
#   Line 5: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_importlib.py
#   Line 1: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/glob.py
#   Line 9: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/package_index.py
#   Line 3: sys
#   Line 4: os
#   Line 7: shutil
#   Line 8: socket
#   Line 894: os.system
#   Line 920: os.system
#   Line 924: os.system
#   Line 939: os.system
#   Line 943: os.system
# File: /usr/local/lib/python3.10/dist-packages/setuptools/launch.py
#   Line 10: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/namespaces.py
#   Line 1: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_path.py
#   Line 1: os
#   Line 2: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/depends.py
#   Line 1: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/installer.py
#   Line 2: os
#   Line 3: subprocess
#   Line 4: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/sandbox.py
#   Line 1: os
#   Line 2: sys
#   Line 9: pickle
# File: /usr/local/lib/python3.10/dist-packages/setuptools/msvc.py
#   Line 16: os
#   Line 21: subprocess
#   Line 27: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/logging.py
#   Line 1: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/wheel.py
#   Line 6: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/warnings.py
#   Line 8: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/discovery.py
#   Line 41: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/dist.py
#   Line 4: sys
#   Line 6: os
#   Line 1217: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/py312compat.py
#   Line 1: sys
#   Line 2: shutil
#   Line 7: shutil.rmtree
#   Line 12: shutil.rmtree
# File: /usr/local/lib/python3.10/dist-packages/setuptools/monkey.py
#   Line 5: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/build_meta.py
#   Line 30: os
#   Line 32: sys
#   Line 34: shutil
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_imp.py
#   Line 6: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/__init__.py
#   Line 4: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/unicode_utils.py
#   Line 2: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/archive_util.py
#   Line 5: os
#   Line 6: shutil
# File: /usr/local/lib/python3.10/dist-packages/setuptools/command/test.py
#   Line 1: os
#   Line 3: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py
#   Line 5: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/command/setopt.py
#   Line 5: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/command/upload_docs.py
#   Line 10: os
#   Line 11: socket
#   Line 14: shutil
#   Line 114: shutil.rmtree
# File: /usr/local/lib/python3.10/dist-packages/setuptools/command/py36compat.py
#   Line 1: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/command/editable_wheel.py
#   Line 14: os
#   Line 15: shutil
#   Line 16: sys
#   Line 725: shutil.rmtree
# File: /usr/local/lib/python3.10/dist-packages/setuptools/command/install_lib.py
#   Line 1: os
#   Line 2: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/command/egg_info.py
#   Line 12: os
#   Line 14: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/command/develop.py
#   Line 4: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/command/install_scripts.py
#   Line 4: os
#   Line 5: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/command/build.py
#   Line 1: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/command/dist_info.py
#   Line 6: os
#   Line 7: shutil
#   Line 8: sys
#   Line 113: shutil.rmtree
# File: /usr/local/lib/python3.10/dist-packages/setuptools/command/bdist_egg.py
#   Line 8: sys
#   Line 9: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/command/build_ext.py
#   Line 1: os
#   Line 2: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/command/easy_install.py
#   Line 24: sys
#   Line 25: os
#   Line 27: shutil
#   Line 38: subprocess
#   Line 1941: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/command/rotate.py
#   Line 4: os
#   Line 5: shutil
#   Line 62: shutil.rmtree
# File: /usr/local/lib/python3.10/dist-packages/setuptools/command/__init__.py
#   Line 2: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/command/install_egg_info.py
#   Line 2: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/command/sdist.py
#   Line 3: os
#   Line 4: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/config/expand.py
#   Line 23: os
#   Line 25: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/config/_apply_pyprojecttoml.py
#   Line 11: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/config/setupcfg.py
#   Line 13: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/config/pyprojecttoml.py
#   Line 12: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/config/_validate_pyproject/formats.py
#   Line 2: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/config/_validate_pyproject/error_reporting.py
#   Line 4: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/extern/__init__.py
#   Line 2: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_vendor/zipp.py
#   Line 6: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_vendor/typing_extensions.py
#   Line 5: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_vendor/importlib_metadata/_compat.py
#   Line 1: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_vendor/importlib_metadata/__init__.py
#   Line 1: os
#   Line 5: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_vendor/jaraco/context.py
#   Line 1: os
#   Line 2: subprocess
#   Line 6: shutil
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_vendor/importlib_resources/_legacy.py
#   Line 2: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_vendor/importlib_resources/_compat.py
#   Line 4: os
#   Line 5: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_vendor/importlib_resources/_common.py
#   Line 1: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_vendor/more_itertools/more.py
#   Line 25: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_vendor/packaging/_elffile.py
#   Line 12: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_vendor/packaging/_manylinux.py
#   Line 4: os
#   Line 6: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_vendor/packaging/markers.py
#   Line 6: os
#   Line 8: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_vendor/packaging/_musllinux.py
#   Line 9: subprocess
#   Line 10: sys
#   Line 50: subprocess.run
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_vendor/packaging/tags.py
#   Line 7: subprocess
#   Line 8: sys
#   Line 399: subprocess.run
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/py39compat.py
#   Line 1: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/text_file.py
#   Line 7: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/msvccompiler.py
#   Line 11: sys
#   Line 12: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/dep_util.py
#   Line 7: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/spawn.py
#   Line 9: sys
#   Line 10: os
#   Line 11: subprocess
#   Line 57: subprocess.Popen
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/_msvccompiler.py
#   Line 16: os
#   Line 17: subprocess
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/unixccompiler.py
#   Line 16: os
#   Line 17: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/core.py
#   Line 9: os
#   Line 10: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/debug.py
#   Line 1: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/fancy_getopt.py
#   Line 11: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/sysconfig.py
#   Line 12: os
#   Line 14: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/filelist.py
#   Line 7: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/msvc9compiler.py
#   Line 15: os
#   Line 16: subprocess
#   Line 17: sys
#   Line 283: subprocess.Popen
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/config.py
#   Line 6: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/dir_util.py
#   Line 5: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/extension.py
#   Line 6: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py
#   Line 7: sys
#   Line 8: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cygwinccompiler.py
#   Line 9: os
#   Line 11: sys
#   Line 15: subprocess
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/dist.py
#   Line 7: sys
#   Line 8: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/bcppcompiler.py
#   Line 15: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/ccompiler.py
#   Line 6: sys
#   Line 7: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/util.py
#   Line 8: os
#   Line 11: subprocess
#   Line 12: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/file_util.py
#   Line 6: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/__init__.py
#   Line 1: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/_macos_compat.py
#   Line 1: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/archive_util.py
#   Line 6: os
#   Line 8: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/build_py.py
#   Line 5: os
#   Line 7: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/build_clib.py
#   Line 17: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/build_scripts.py
#   Line 5: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/bdist.py
#   Line 6: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/install_data.py
#   Line 8: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/upload.py
#   Line 8: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/bdist_dumb.py
#   Line 7: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/install.py
#   Line 5: sys
#   Line 6: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/config.py
#   Line 12: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/_framework_compat.py
#   Line 6: sys
#   Line 7: os
#   Line 9: subprocess
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/py37compat.py
#   Line 1: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/clean.py
#   Line 7: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/install_lib.py
#   Line 6: os
#   Line 8: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/install_scripts.py
#   Line 8: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/build.py
#   Line 5: sys
#   Line 6: os
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/bdist_rpm.py
#   Line 6: subprocess
#   Line 7: sys
#   Line 8: os
#   Line 361: os.popen
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/build_ext.py
#   Line 8: os
#   Line 10: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/install_egg_info.py
#   Line 8: os
#   Line 9: sys
# File: /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/command/sdist.py
#   Line 5: os
#   Line 6: sys
# File: /usr/local/lib/python3.10/dist-packages/build/_ctx.py
#   Line 5: subprocess
#   Line 54: subprocess.Popen
#   Line 71: subprocess.run
# File: /usr/local/lib/python3.10/dist-packages/build/env.py
#   Line 6: os
#   Line 8: shutil
#   Line 9: subprocess
#   Line 10: sys
#   Line 103: shutil.rmtree
# File: /usr/local/lib/python3.10/dist-packages/build/_exceptions.py
#   Line 3: subprocess
# File: /usr/local/lib/python3.10/dist-packages/build/_types.py
#   Line 3: os
# File: /usr/local/lib/python3.10/dist-packages/build/__main__.py
#   Line 8: os
#   Line 10: shutil
#   Line 11: subprocess
#   Line 12: sys
#   Line 284: shutil.rmtree
# File: /usr/local/lib/python3.10/dist-packages/build/_builder.py
#   Line 7: os
#   Line 8: subprocess
#   Line 9: sys
# File: /usr/local/lib/python3.10/dist-packages/build/_compat/tarfile.py
#   Line 3: sys
# File: /usr/local/lib/python3.10/dist-packages/build/_compat/tomllib.py
#   Line 3: sys
# File: /usr/local/lib/python3.10/dist-packages/build/_compat/importlib.py
#   Line 3: sys
# File: /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py
#   Line 23: sys
#   Line 24: os
#   Line 61: os
#   Line 64: os
#   Line 71: os
# File: /usr/local/lib/python3.10/dist-packages/pkg_resources/extern/__init__.py
#   Line 2: sys
# File: /usr/local/lib/python3.10/dist-packages/pkg_resources/_vendor/zipp.py
#   Line 6: sys
# File: /usr/local/lib/python3.10/dist-packages/pkg_resources/_vendor/typing_extensions.py
#   Line 6: sys
# File: /usr/local/lib/python3.10/dist-packages/pkg_resources/_vendor/platformdirs/android.py
#   Line 3: os
#   Line 5: sys
# File: /usr/local/lib/python3.10/dist-packages/pkg_resources/_vendor/platformdirs/macos.py
#   Line 3: os
# File: /usr/local/lib/python3.10/dist-packages/pkg_resources/_vendor/platformdirs/windows.py
#   Line 4: os
#   Line 5: sys
# File: /usr/local/lib/python3.10/dist-packages/pkg_resources/_vendor/platformdirs/unix.py
#   Line 3: os
#   Line 4: sys
#   Line 11: os
# File: /usr/local/lib/python3.10/dist-packages/pkg_resources/_vendor/platformdirs/api.py
#   Line 3: os
#   Line 4: sys
# File: /usr/local/lib/python3.10/dist-packages/pkg_resources/_vendor/platformdirs/__init__.py
#   Line 7: os
#   Line 8: sys
# File: /usr/local/lib/python3.10/dist-packages/pkg_resources/_vendor/jaraco/context.py
#   Line 1: os
#   Line 2: subprocess
#   Line 6: shutil
# File: /usr/local/lib/python3.10/dist-packages/pkg_resources/_vendor/importlib_resources/_legacy.py
#   Line 2: os
# File: /usr/local/lib/python3.10/dist-packages/pkg_resources/_vendor/importlib_resources/_compat.py
#   Line 4: os
#   Line 5: sys
# File: /usr/local/lib/python3.10/dist-packages/pkg_resources/_vendor/importlib_resources/_common.py
#   Line 1: os
# File: /usr/local/lib/python3.10/dist-packages/pkg_resources/_vendor/more_itertools/more.py
#   Line 25: sys
# File: /usr/local/lib/python3.10/dist-packages/pkg_resources/_vendor/packaging/_elffile.py
#   Line 12: os
# File: /usr/local/lib/python3.10/dist-packages/pkg_resources/_vendor/packaging/_manylinux.py
#   Line 4: os
#   Line 6: sys
# File: /usr/local/lib/python3.10/dist-packages/pkg_resources/_vendor/packaging/markers.py
#   Line 6: os
#   Line 8: sys
# File: /usr/local/lib/python3.10/dist-packages/pkg_resources/_vendor/packaging/_musllinux.py
#   Line 9: subprocess
#   Line 10: sys
#   Line 50: subprocess.run
# File: /usr/local/lib/python3.10/dist-packages/pkg_resources/_vendor/packaging/tags.py
#   Line 7: subprocess
#   Line 8: sys
#   Line 399: subprocess.run

# %% [markdown]
# **Method 2:  bandit**
# bandit is a static analysis tool in python which can be used to create call graphs. We will be using bandit for creating call graph for *pandas* and its filtered dependencies. For simplicity, we will be looking at methods that has ***high*** severity.
#
# please install bandit using:
#
# ```
# pip install bandit
# ```

# %%
# !bandit -r '/usr/local/lib/python3.10/dist-packages/pandas' --severity high
# !bandit -r '/usr/local/lib/python3.10/dist-packages/sqlalchemy' --severity high
# !bandit -r '/usr/local/lib/python3.10/dist-packages/requests' --severity high
# !bandit -r '/usr/local/lib/python3.10/dist-packages/fsspec' --severity high
# !bandit -r '/usr/local/lib/python3.10/dist-packages/bs4' --severity high
# !bandit -r '/usr/local/lib/python3.10/dist-packages/pymysql' --severity high
# Out:
# [main]	INFO	profile include tests: None
# [main]	INFO	profile exclude tests: None
# [main]	INFO	cli include tests: None
# [main]	INFO	cli exclude tests: None
# [main]	INFO	running on Python 3.10.12
# Working... ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 0:01:05
# [main]	INFO	profile include tests: None
# [main]	INFO	profile exclude tests: None
# [main]	INFO	cli include tests: None
# [main]	INFO	cli exclude tests: None
# [main]	INFO	running on Python 3.10.12
# Working... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:26
# Run started:2024-05-19 14:14:27.860749
#
# Test results:
# >> Issue: [B324:hashlib] Use of weak MD5 hash for security. Consider usedforsecurity=False
#    Severity: High   Confidence: High
#    CWE: CWE-327 (https://cwe.mitre.org/data/definitions/327.html)
#    More Info: https://bandit.readthedocs.io/en/1.7.8/plugins/b324_hashlib.html
#    Location: /usr/local/lib/python3.10/dist-packages/sqlalchemy/util/compat.py:112:15
# 111	    def md5_not_for_security() -> Any:
# 112	        return hashlib.md5()
# 113
#
# --------------------------------------------------
#
# Code scanned:
# 	Total lines of code: 174933
# 	Total lines skipped (#nosec): 0
#
# Run metrics:
# 	Total issues (by severity):
# 		Undefined: 0
# 		Low: 732
# 		Medium: 40
# 		High: 1
# 	Total issues (by confidence):
# 		Undefined: 0
# 		Low: 24
# 		Medium: 11
# 		High: 738
# Files skipped (0):
# [main]	INFO	profile include tests: None
# [main]	INFO	profile exclude tests: None
# [main]	INFO	cli include tests: None
# [main]	INFO	cli exclude tests: None
# [main]	INFO	running on Python 3.10.12
# Run started:2024-05-19 14:14:29.180639
#
# Test results:
# >> Issue: [B324:hashlib] Use of weak MD5 hash for security. Consider usedforsecurity=False
#    Severity: High   Confidence: High
#    CWE: CWE-327 (https://cwe.mitre.org/data/definitions/327.html)
#    More Info: https://bandit.readthedocs.io/en/1.7.8/plugins/b324_hashlib.html
#    Location: /usr/local/lib/python3.10/dist-packages/requests/auth.py:148:23
# 147	                    x = x.encode("utf-8")
# 148	                return hashlib.md5(x).hexdigest()
# 149
#
# --------------------------------------------------
# >> Issue: [B324:hashlib] Use of weak SHA1 hash for security. Consider usedforsecurity=False
#    Severity: High   Confidence: High
#    CWE: CWE-327 (https://cwe.mitre.org/data/definitions/327.html)
#    More Info: https://bandit.readthedocs.io/en/1.7.8/plugins/b324_hashlib.html
#    Location: /usr/local/lib/python3.10/dist-packages/requests/auth.py:156:23
# 155	                    x = x.encode("utf-8")
# 156	                return hashlib.sha1(x).hexdigest()
# 157
#
# --------------------------------------------------
# >> Issue: [B324:hashlib] Use of weak SHA1 hash for security. Consider usedforsecurity=False
#    Severity: High   Confidence: High
#    CWE: CWE-327 (https://cwe.mitre.org/data/definitions/327.html)
#    More Info: https://bandit.readthedocs.io/en/1.7.8/plugins/b324_hashlib.html
#    Location: /usr/local/lib/python3.10/dist-packages/requests/auth.py:205:17
# 204
# 205	        cnonce = hashlib.sha1(s).hexdigest()[:16]
# 206	        if _algorithm == "MD5-SESS":
#
# --------------------------------------------------
#
# Code scanned:
# 	Total lines of code: 3945
# 	Total lines skipped (#nosec): 0
#
# Run metrics:
# 	Total issues (by severity):
# 		Undefined: 0
# 		Low: 6
# 		Medium: 0
# 		High: 3
# 	Total issues (by confidence):
# 		Undefined: 0
# 		Low: 0
# 		Medium: 0
# 		High: 9
# Files skipped (0):
# [main]	INFO	profile include tests: None
# [main]	INFO	profile exclude tests: None
# [main]	INFO	cli include tests: None
# [main]	INFO	cli exclude tests: None
# [main]	INFO	running on Python 3.10.12
# Run started:2024-05-19 14:14:33.567332
#
# Test results:
# >> Issue: [B402:blacklist] A FTP-related module is being imported.  FTP is considered insecure. Use SSH/SFTP/SCP or some other encrypted protocol.
#    Severity: High   Confidence: High
#    CWE: CWE-319 (https://cwe.mitre.org/data/definitions/319.html)
#    More Info: https://bandit.readthedocs.io/en/1.7.8/blacklists/blacklist_imports.html#b402-import-ftplib
#    Location: /usr/local/lib/python3.10/dist-packages/fsspec/implementations/ftp.py:5:0
# 4	import warnings
# 5	from ftplib import FTP, Error, error_perm
# 6	from typing import Any
#
# --------------------------------------------------
# >> Issue: [B321:blacklist] FTP-related functions are being called. FTP is considered insecure. Use SSH/SFTP/SCP or some other encrypted protocol.
#    Severity: High   Confidence: High
#    CWE: CWE-319 (https://cwe.mitre.org/data/definitions/319.html)
#    More Info: https://bandit.readthedocs.io/en/1.7.8/blacklists/blacklist_calls.html#b321-ftplib
#    Location: /usr/local/lib/python3.10/dist-packages/fsspec/implementations/ftp.py:75:23
# 74	        if sys.version_info >= (3, 9):
# 75	            self.ftp = FTP(timeout=self.timeout, encoding=self.encoding)
# 76	        elif self.encoding:
#
# --------------------------------------------------
# >> Issue: [B321:blacklist] FTP-related functions are being called. FTP is considered insecure. Use SSH/SFTP/SCP or some other encrypted protocol.
#    Severity: High   Confidence: High
#    CWE: CWE-319 (https://cwe.mitre.org/data/definitions/319.html)
#    More Info: https://bandit.readthedocs.io/en/1.7.8/blacklists/blacklist_calls.html#b321-ftplib
#    Location: /usr/local/lib/python3.10/dist-packages/fsspec/implementations/ftp.py:78:23
# 77	            warnings.warn("`encoding` not supported for python<3.9, ignoring")
# 78	            self.ftp = FTP(timeout=self.timeout)
# 79	        else:
#
# --------------------------------------------------
# >> Issue: [B321:blacklist] FTP-related functions are being called. FTP is considered insecure. Use SSH/SFTP/SCP or some other encrypted protocol.
#    Severity: High   Confidence: High
#    CWE: CWE-319 (https://cwe.mitre.org/data/definitions/319.html)
#    More Info: https://bandit.readthedocs.io/en/1.7.8/blacklists/blacklist_calls.html#b321-ftplib
#    Location: /usr/local/lib/python3.10/dist-packages/fsspec/implementations/ftp.py:80:23
# 79	        else:
# 80	            self.ftp = FTP(timeout=self.timeout)
# 81	        self.ftp.connect(self.host, self.port)
#
# --------------------------------------------------
# >> Issue: [B507:ssh_no_host_key_verification] Paramiko call with policy set to automatically trust the unknown host key.
#    Severity: High   Confidence: Medium
#    CWE: CWE-295 (https://cwe.mitre.org/data/definitions/295.html)
#    More Info: https://bandit.readthedocs.io/en/1.7.8/plugins/b507_ssh_no_host_key_verification.html
#    Location: /usr/local/lib/python3.10/dist-packages/fsspec/implementations/sftp.py:53:8
# 52	        self.client = paramiko.SSHClient()
# 53	        self.client.set_missing_host_key_policy(paramiko.AutoAddPolicy())
# 54	        self.client.connect(self.host, **self.ssh_kwargs)
#
# --------------------------------------------------
# >> Issue: [B324:hashlib] Use of weak MD5 hash for security. Consider usedforsecurity=False
#    Severity: High   Confidence: High
#    CWE: CWE-327 (https://cwe.mitre.org/data/definitions/327.html)
#    More Info: https://bandit.readthedocs.io/en/1.7.8/plugins/b324_hashlib.html
#    Location: /usr/local/lib/python3.10/dist-packages/fsspec/utils.py:287:15
# 286	    try:
# 287	        return md5(str(args).encode()).hexdigest()
# 288	    except ValueError:
#
# --------------------------------------------------
#
# Code scanned:
# 	Total lines of code: 14048
# 	Total lines skipped (#nosec): 0
#
# Run metrics:
# 	Total issues (by severity):
# 		Undefined: 0
# 		Low: 289
# 		Medium: 10
# 		High: 6
# 	Total issues (by confidence):
# 		Undefined: 0
# 		Low: 6
# 		Medium: 3
# 		High: 296
# Files skipped (0):
# [main]	INFO	profile include tests: None
# [main]	INFO	profile exclude tests: None
# [main]	INFO	cli include tests: None
# [main]	INFO	cli exclude tests: None
# [main]	INFO	running on Python 3.10.12
# Run started:2024-05-19 14:14:35.687041
#
# Test results:
# 	No issues identified.
#
# Code scanned:
# 	Total lines of code: 9177
# 	Total lines skipped (#nosec): 0
#
# Run metrics:
# 	Total issues (by severity):
# 		Undefined: 0
# 		Low: 803
# 		Medium: 8
# 		High: 0
# 	Total issues (by confidence):
# 		Undefined: 0
# 		Low: 0
# 		Medium: 0
# 		High: 811
# Files skipped (0):
# [main]	INFO	profile include tests: None
# [main]	INFO	profile exclude tests: None
# [main]	INFO	cli include tests: None
# [main]	INFO	cli exclude tests: None
# [main]	INFO	running on Python 3.10.12
# Run started:2024-05-19 14:14:36.088660
#
# Test results:
# 	No issues identified.
#
# Code scanned:
# 	Total lines of code: 0
# 	Total lines skipped (#nosec): 0
#
# Run metrics:
# 	Total issues (by severity):
# 		Undefined: 0
# 		Low: 0
# 		Medium: 0
# 		High: 0
# 	Total issues (by confidence):
# 		Undefined: 0
# 		Low: 0
# 		Medium: 0
# 		High: 0
# Files skipped (1):
# 	/usr/local/lib/python3.10/dist-packages/pymysql (No such file or directory)

# %% [markdown]
# #####Conclusion:
#
# The Modules analysis using ast along with call graph can be used to replace / prune unsafe operations based on priority.

# %% [markdown]
# ### Task 3: Pruning unsafe Features
#
# Pruning such methods can be performed by monkey-catching such instances. For example let's consider the following code which tries to read and write a csv.
#
#
# ```
# import pandas as pd
#
# # Example usage
# data = pd.read_csv('/tmp/unsafe_data.csv')
# data.to_csv(, '/tmp/unsafe_data_copy.csv')
# ```
#
# This file reads data from an arbitrary filepath which maybe harmful.
# To fix this without affecting the code functionality, we can describe a SAFE_DIRECTORY where read&write functions are allowed. The function may only work in such instances.
#
# Code:
#
# ```
# import pandas as pd
# import os
#
# # Define safe directory
# SAFE_DIRECTORY = '/safe/directory/'
#
# # Original functions
# _original_read_csv = pd.read_csv
# _original_to_csv = pd.DataFrame.to_csv
#
# # Safe read_csv function
# def safe_read_csv(file_path, *args, **kwargs):
#     if not file_path.startswith(SAFE_DIRECTORY):
#         raise PermissionError("Unsafe file operation detected")
#     return _original_read_csv(file_path, *args, **kwargs)
#
# # Safe to_csv function
# def safe_to_csv(self, file_path, *args, **kwargs):
#     if not file_path.startswith(SAFE_DIRECTORY):
#         raise PermissionError("Unsafe file operation detected")
#     return _original_to_csv(self, file_path, *args, **kwargs)
#
# # Apply monkey patch
# pd.read_csv = safe_read_csv
# pd.DataFrame.to_csv = safe_to_csv
#
# # Example of Pandas code using the monkey-patched functions
# def read_data(file_path):
#     return pd.read_csv(file_path)
#
# def write_data(data, file_path):
#     data.to_csv(file_path)
#
# # Example usage
# try:
#     data = read_data('/safe/directory/unsafe_data.csv')
#     write_data(data, '/safe/directory/unsafe_data_copy.csv')
# except PermissionError as e:
#     print(e)
# ```
